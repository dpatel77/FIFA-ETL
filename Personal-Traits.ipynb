# %%
import pandas as pd
import requests

from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
world = "Resources/WorldCups.csv"
world
# Out:
# 'Resources/WorldCups.csv'

# %%
players = "Resources/players_20.csv"
players
# Out:
# 'Resources/players_20.csv'

# %%
clubs = "Resources/clubs.csv"
clubs
# Out:
# 'Resources/clubs.csv'

# %% [markdown]
# ### Transform Clubs DataFrame

# %%
#Create Clubs Dataframe
clubs_df = pd.read_csv(clubs)
clubs_df.head()
# Out:
#    Edition  Season   Hosts             Champions                 Score  \
# 0      1.0    2000  Brazil      Corinthians[n 2]                   0–0
# 1      NaN    2001   Spain  Tournament cancelled  Tournament cancelled
# 2      2.0    2005   Japan             São Paulo                   1–0
# 3      3.0    2006   Japan         Internacional                   1–0
# 4      4.0    2007   Japan                 Milan                   4–2
#
#              Runners-up              Third place               Score.1  \
# 0         Vasco da Gama              Necaxa[n 3]                   1–1
# 1  Tournament cancelled     Tournament cancelled  Tournament cancelled
# 2             Liverpool                 Saprissa                   3–2
# 3             Barcelona                  Al Ahly                   2–1
# 4          Boca Juniors  Urawa Red Diamonds[n 4]                   2–2
#
#            Fourth place         Ref
# 0           Real Madrid  [138][139]
# 1  Tournament cancelled       [140]
# ...

# %%
#Filter Clubs Dataframe to Find 2019 Champions
winner_2019 = clubs_df[clubs_df['Season']==2019]
winner_2019
# Out:
#     Edition  Season  Hosts        Champions Score Runners-up      Third place  \
# 16     16.0    2019  Qatar  Liverpool[n 11]   1–0   Flamengo  Monterrey[n 12]
#
#    Score.1 Fourth place    Ref
# 16     2–2     Al-Hilal  [129]

# %% [markdown]
# ### Transform Players DataFrame

# %%
players_df = pd.read_csv(players)
players_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age        dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  6/24/1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34   2/5/1985
# 2          Neymar Jr        Neymar da Silva Santos Junior   27   2/5/1992
# 3           J. Oblak                            Jan Oblak   26   1/7/1993
# 4          E. Hazard                          Eden Hazard   28   1/7/1991
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
#Filter Players Dataframe to Find Players from Liverpool, ie. Champions in 2019
liverpool_players = players_df[players_df['club']=="Liverpool"]
liverpool_players
# Out:
#        sofifa_id                                         player_url  \
# 7         203376  https://sofifa.com/player/203376/virgil-van-di...
# 9         209331  https://sofifa.com/player/209331/mohamed-salah...
# 13        212831  https://sofifa.com/player/212831/alisson-ramse...
# 39        208722  https://sofifa.com/player/208722/sadio-mane/20...
# 63        201942  https://sofifa.com/player/201942/roberto-firmi...
# 81        209499  https://sofifa.com/player/209499/fabio-henriqu...
# 82        216267  https://sofifa.com/player/216267/andrew-robert...
# 139       181291  https://sofifa.com/player/181291/georginio-wij...
# 160       231281  https://sofifa.com/player/231281/trent-alexand...
# 218       183711  https://sofifa.com/player/183711/jordan-hender...
# 243       220971  https://sofifa.com/player/220971/naby-keita/20...
# 260       197061  https://sofifa.com/player/197061/joel-matip/20...
# 313       193348  https://sofifa.com/player/193348/xherdan-shaqi...
# ...

# %%
#Display Summary of Liverpool Players 
liverpool_players_traits = liverpool_players[["short_name","sofifa_id","club", "player_url","age","dob","player_traits"]]
liverpool_players_traits
# Out:
#                   short_name  sofifa_id       club  \
# 7                V. van Dijk     203376  Liverpool
# 9                   M. Salah     209331  Liverpool
# 13                   Alisson     212831  Liverpool
# 39                   S. Mané     208722  Liverpool
# 63           Roberto Firmino     201942  Liverpool
# 81                   Fabinho     209499  Liverpool
# 82              A. Robertson     216267  Liverpool
# 139             G. Wijnaldum     181291  Liverpool
# 160      T. Alexander-Arnold     231281  Liverpool
# 218             J. Henderson     183711  Liverpool
# 243                 N. Keïta     220971  Liverpool
# 260                 J. Matip     197061  Liverpool
# 313               X. Shaqiri     193348  Liverpool
# 371                J. Milner     138412  Liverpool
# 413                 J. Gomez     225100  Liverpool
# 451    A. Oxlade-Chamberlain     198784  Liverpool
# 542                D. Lovren     195086  Liverpool
# ...

# %%
# Create a Index of Personal Traits of Players
#s = liverpool_players_traits.Series(['player_traits',
               #np.nan])
    
#df['player_traits'] = liverpool_players_traits['player_traits'].str.extract(r'([^\/,]+)', expand=True)
#df
#df['clsfr'] = df['player_trait'].str.extract(r'([^\/]+)', expand=True)

# Calling DataFrame constructor on list
liverpool_players_traits_index = pd.DataFrame()
liverpool_players_traits_index["Traits"] = liverpool_players_traits['player_traits'].str.split(',').str[0]
liverpool_players_traits_index.head()
# Out:
#                Traits
# 7               Diver
# 9   Beat Offside Trap
# 13              Flair
# 39            Selfish
# 63            Selfish
